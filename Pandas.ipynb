# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.2.4

# %%
s = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
type(s.values)
# Out:
# numpy.ndarray

# %%
s[1]
# Out:
# 2

# %%
s['b']
# Out:
# 2

# %%
s['b':'d']
# Out:
# b    2
# c    3
# d    4
# dtype: int64

# %%
s[1:3]
# Out:
# b    2
# c    3
# dtype: int64

# %%
serie1 = pd.Series({'a':78, 'b':79, 'c':80})

# %%
serie1
# Out:
# a    78
# b    79
# c    80
# dtype: int64

# %%
serie1.values
# Out:
# array([78, 79, 80], dtype=int64)

# %%
serie1.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
serie2 = pd.Series({'a':10, 'b':11, 'c':12})

# %%
serie2.values
# Out:
# array([10, 11, 12], dtype=int64)

# %%
serie2
# Out:
# a    10
# b    11
# c    12
# dtype: int64

# %%
dataframe = pd.DataFrame({'serie 1':serie1, 'serie 2':serie2})
dataframe
# Out:
#    serie 1  serie 2
# a       78       10
# b       79       11
# c       80       12

# %%
dataframe.T
# Out:
#           a   b   c
# serie 1  78  79  80
# serie 2  10  11  12

# %%
dataframe.values
# Out:
# array([[78, 10],
#        [79, 11],
#        [80, 12]], dtype=int64)

# %%
dataframe.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
dataframe.columns
# Out:
# Index(['serie 1', 'serie 2'], dtype='object')

# %%
dataframe.values[1,0]
# Out:
# 79

# %%
dataframe1 = dataframe
dataframe1
# Out:
#    serie 1  serie 2
# a       78       10
# b       79       11
# c       80       12

# %%
dataframe1['Total series'] = dataframe1['serie 1'] + dataframe1['serie 2']
dataframe1
# Out:
#    serie 1  serie 2  Total series
# a       78       10            88
# b       79       11            90
# c       80       12            92

# %%
dataframe1
# Out:
#    serie 1  serie 2  Total series
# a       78       10            88
# b       79       11            90
# c       80       12            92

# %%
del dataframe1['Total series']
dataframe1
# Out:
#    serie 1  serie 2
# a       78       10
# b       79       11
# c       80       12

# %%
dataframe1.loc['a']
# Out:
# serie 1    78
# serie 2    10
# Name: a, dtype: int64

# %%
dataframe1.loc[['a','b']]
# Out:
#    serie 1  serie 2
# a       78       10
# b       79       11

# %%
dataframe1.iloc[0]
# Out:
# serie 1    78
# serie 2    10
# Name: a, dtype: int64

# %%
dataframeSearch = dataframe1[dataframe1['serie 1']>=79]
dataframeSearch
# Out:
#    serie 1  serie 2
# b       79       11
# c       80       12

# %%
minutes = pd.Series([60,45,30,45,45,4500], index=[0,1,2,3,4,5])

# %%
rate = pd.Series([4,4,8,7,10], index=[0,1,3,4,5])

# %%
ask = pd.Series([1,'cero',2,2,3], index=[1,2,3,4,5])

# %%
dfClass = pd.DataFrame({'Time':minutes, 'Rate':rate, 'Ask':ask})

# %%
dfClass
# Out:
#    Time  Rate   Ask
# 0    60   4.0   NaN
# 1    45   4.0     1
# 2    30   NaN  cero
# 3    45   8.0     2
# 4    45   7.0     2
# 5  4500  10.0     3

# %%
dfNewClass = dfClass.dropna()
dfNewClass
# Out:
#    Time  Rate Ask
# 1    45   4.0   1
# 3    45   8.0   2
# 4    45   7.0   2
# 5  4500  10.0   3

# %%
dfClass
# Out:
#    Time  Rate   Ask
# 0    60   4.0   NaN
# 1    45   4.0     1
# 2    30   NaN  cero
# 3    45   8.0     2
# 4    45   7.0     2
# 5  4500  10.0     3

# %%
dfClass
# Out:
#    Time  Rate   Ask
# 0    60   4.0   NaN
# 1    45   4.0     1
# 2    30   NaN  cero
# 3    45   8.0     2
# 4    45   7.0     2
# 5  4500  10.0     3

# %%
dfClass.fillna(333, inplace= True)
dfClass
# Out:
#    Time   Rate   Ask
# 0    60    4.0   333
# 1    45    4.0     1
# 2    30  333.0  cero
# 3    45    8.0     2
# 4    45    7.0     2
# 5  4500   10.0     3

# %%
dfClass = pd.DataFrame({'Time':minutes, 'Rate':rate, 'Ask':ask})
dfClass
# Out:
#    Time  Rate   Ask
# 0    60   4.0   NaN
# 1    45   4.0     1
# 2    30   NaN  cero
# 3    45   8.0     2
# 4    45   7.0     2
# 5  4500  10.0     3

# %%
dfClass['Rate'].fillna(7, inplace=True)
dfClass
# Out:
#    Time  Rate   Ask
# 0    60   4.0   NaN
# 1    45   4.0     1
# 2    30   7.0  cero
# 3    45   8.0     2
# 4    45   7.0     2
# 5  4500  10.0     3

# %%
dfClass = pd.DataFrame({'Time':minutes, 'Rate':rate, 'Ask':ask})
dfClass
# Out:
#    Time  Rate   Ask
# 0    60   4.0   NaN
# 1    45   4.0     1
# 2    30   NaN  cero
# 3    45   8.0     2
# 4    45   7.0     2
# 5  4500  10.0     3

# %%
mean = dfClass['Rate'].mean()
mean
# Out:
# 6.6

# %%
median = dfClass['Rate'].median()
median
# Out:
# 7.0

# %%
mode = dfClass['Rate'].mode()
mode
# Out:
# 0    4.0
# dtype: float64

# %%
dfClass = pd.DataFrame({'Time':minutes, 'Rate':rate, 'Ask':ask})
dfClass
# Out:
#    Time  Rate   Ask
# 0    60   4.0   NaN
# 1    45   4.0     1
# 2    30   NaN  cero
# 3    45   8.0     2
# 4    45   7.0     2
# 5  4500  10.0     3

# %%
dfClass.Ask
# Out:
# 0     NaN
# 1       1
# 2    cero
# 3       2
# 4       2
# 5       3
# Name: Ask, dtype: object

# %%
dfClass.Ask[dfClass.Ask =='cero']=0
dfClass
# Out:
# <ipython-input-284-d8fa75173bde>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass.Ask[dfClass.Ask =='cero']=0
#    Time  Rate  Ask
# 0    60   4.0  NaN
# 1    45   4.0    1
# 2    30   NaN    0
# 3    45   8.0    2
# 4    45   7.0    2
# 5  4500  10.0    3

# %%
dfClass.loc[5,'Time']=45
dfClass
# Out:
#    Time  Rate  Ask
# 0    60   4.0  NaN
# 1    45   4.0    1
# 2    30   NaN    0
# 3    45   8.0    2
# 4    45   7.0    2
# 5    45  10.0    3

# %%
dfClass.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
dfClass.loc[6, 'Time']=45
dfClass.loc[6, 'Rate']=7
dfClass.loc[6, 'Ask']=2
dfClass
# Out:
#    Time  Rate  Ask
# 0  60.0   4.0  NaN
# 1  45.0   4.0    1
# 2  30.0   NaN    0
# 3  45.0   8.0    2
# 4  45.0   7.0    2
# 5  45.0  10.0    3
# 6  45.0   7.0    2

# %%
dfClass.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
dfClass.drop_duplicates(inplace=True)
dfClass
# Out:
#    Time  Rate  Ask
# 0  60.0   4.0  NaN
# 1  45.0   4.0    1
# 2  30.0   NaN    0
# 3  45.0   8.0    2
# 4  45.0   7.0    2
# 5  45.0  10.0    3

# %%
df =pd.read_csv('movies.csv')
df
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         10000 non-null  int64
#  1   Title        10000 non-null  object
#  2   Year         10000 non-null  int64
#  3   Score        10000 non-null  float64
#  4   Metascore    6781 non-null   float64
#  5   Genre        10000 non-null  object
#  6   Vote         10000 non-null  int64
#  7   Director     9999 non-null   object
#  8   Runtime      10000 non-null  int64
#  9   Revenue      7473 non-null   float64
#  10  Description  10000 non-null  object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 859.5+ KB

# %%
pd.set_option('display.max_columns',11)
df
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# ...

# %%
df.head(40)
# Out:
#     Rank                                              Title  Year  Score  \
# 0      1                           The Shawshank Redemption  1994    9.3
# 1      2                                    The Dark Knight  2008    9.0
# 2      3                                          Inception  2010    8.8
# 3      4                                         Fight Club  1999    8.8
# 4      5                                       Pulp Fiction  1994    8.9
# 5      6                                       Forrest Gump  1994    8.8
# 6      7  The Lord of the Rings: The Fellowship of the Ring  2001    8.8
# 7      8                                         The Matrix  1999    8.7
# 8      9      The Lord of the Rings: The Return of the King  2003    8.9
# 9     10                                      The Godfather  1972    9.2
# 10    11                              The Dark Knight Rises  2012    8.4
# 11    12              The Lord of the Rings: The Two Towers  2002    8.7
# ...

# %%
df.tail(20)
# Out:
#        Rank                                   Title  Year  Score  Metascore  \
# 9980   9981                    Smetto quando voglio  2014    7.1        NaN
# 9981   9982                                Phase IV  1974    6.6        NaN
# 9982   9983                       Shirley Valentine  1989    7.2       52.0
# 9983   9984            Let's Scare Jessica to Death  1971    6.5        NaN
# 9984   9985                              Stone Cold  1991    5.9        NaN
# 9985   9986                          Things to Come  1936    6.7        NaN
# 9986   9987                                  Paisan  1946    7.7        NaN
# 9987   9988                            Agnes of God  1985    6.6        NaN
# 9988   9989                        Le Notti Bianche  1957    7.8        NaN
# 9989   9990                       The Narrow Margin  1952    7.7        NaN
# 9990   9991                                 Starlet  2012    6.8       74.0
# ...

# %%
df['Score']
# Out:
# 0       9.3
# 1       9.0
# 2       8.8
# 3       8.8
# 4       8.9
#        ...
# 9995    6.6
# 9996    7.6
# 9997    5.3
# 9998    7.3
# 9999    5.0
# Name: Score, Length: 10000, dtype: float64

# %%
df.Score
# Out:
# 0       9.3
# 1       9.0
# 2       8.8
# 3       8.8
# 4       8.9
#        ...
# 9995    6.6
# 9996    7.6
# 9997    5.3
# 9998    7.3
# 9999    5.0
# Name: Score, Length: 10000, dtype: float64

# %%
df[['Score', 'Metascore']]
# Out:
#       Score  Metascore
# 0       9.3       80.0
# 1       9.0       84.0
# 2       8.8       74.0
# 3       8.8       66.0
# 4       8.9       94.0
# ...     ...        ...
# 9995    6.6        NaN
# 9996    7.6        NaN
# 9997    5.3       31.0
# 9998    7.3        NaN
# 9999    5.0        NaN
#
# [10000 rows x 2 columns]

# %%
df[['Score', 'Metascore', 'Vote']]
# Out:
#       Score  Metascore     Vote
# 0       9.3       80.0  2011509
# 1       9.0       84.0  1980200
# 2       8.8       74.0  1760209
# 3       8.8       66.0  1609459
# 4       8.9       94.0  1570194
# ...     ...        ...      ...
# 9995    6.6        NaN     6022
# 9996    7.6        NaN     6021
# 9997    5.3       31.0     6020
# 9998    7.3        NaN     6018
# 9999    5.0        NaN     6015
#
# [10000 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Year', 'Score', 'Metascore', 'Genre', 'Vote',
#        'Director', 'Runtime', 'Revenue', 'Description'],
#       dtype='object')

# %%
df.loc[200]
# Out:
# Rank                                                         201
# Title                                             Doctor Strange
# Year                                                        2016
# Score                                                        7.5
# Metascore                                                   72.0
# Genre                                 Action, Adventure, Fantasy
# Vote                                                      456589
# Director                                        Scott Derrickson
# Runtime                                                      115
# Revenue                                                   232.64
# Description    While on a journey of physical and spiritual h...
# Name: 200, dtype: object

# %%
df.loc[[0,1]]
# Out:
#    Rank                     Title  Year  Score  Metascore  \
# 0     1  The Shawshank Redemption  1994    9.3       80.0
# 1     2           The Dark Knight  2008    9.0       84.0
#
#                   Genre     Vote           Director  Runtime  Revenue  \
# 0                 Drama  2011509     Frank Darabont      142    28.34
# 1  Action, Crime, Drama  1980200  Christopher Nolan      152   534.86
#
#                                          Description
# 0  Two imprisoned men bond over a number of years...
# 1  When the menace known as the Joker emerges fro...

# %%
df.loc[[0,1,2], 'Genre']
# Out:
# 0                        Drama
# 1         Action, Crime, Drama
# 2    Action, Adventure, Sci-Fi
# Name: Genre, dtype: object

# %%
df.iloc[[0,1,2], 5]
# Out:
# 0                        Drama
# 1         Action, Crime, Drama
# 2    Action, Adventure, Sci-Fi
# Name: Genre, dtype: object

# %%
df.loc[[0,1], ['Year','Title']]
# Out:
#    Year                     Title
# 0  1994  The Shawshank Redemption
# 1  2008           The Dark Knight

# %%
df['Score'].value_counts()
# Out:
# 7.2    431
# 7.3    422
# 7.1    391
# 6.8    387
# 6.6    386
#       ...
# 1.5      1
# 1.6      1
# 9.2      1
# 9.3      1
# 1.7      1
# Name: Score, Length: 82, dtype: int64

# %%
df['Genre'].value_counts()
# Out:
# Comedy, Drama, Romance       494
# Drama                        482
# Comedy, Drama                407
# Drama, Romance               365
# Comedy                       357
#                             ...
# Comedy, Adventure, Family      1
# Adventure, War                 1
# Adventure, Music, Mystery      1
# Adventure                      1
# Action, Fantasy, War           1
# Name: Genre, Length: 486, dtype: int64

# %%
df['Director'].value_counts()
# Out:
# Woody Allen             48
# Alfred Hitchcock        38
# Clint Eastwood          35
# Steven Spielberg        31
# Steven Soderbergh       25
#                         ..
# John D. Hancock          1
# Chris Robinson           1
# Klay Hall                1
# John Stainton            1
# William Peter Blatty     1
# Name: Director, Length: 3907, dtype: int64

# %%
df.loc[[0,5,10], 'Director']
# Out:
# 0        Frank Darabont
# 5       Robert Zemeckis
# 10    Christopher Nolan
# Name: Director, dtype: object

# %%
df.loc[0:10, ['Director', 'Revenue']]
# Out:
#                 Director  Revenue
# 0         Frank Darabont    28.34
# 1      Christopher Nolan   534.86
# 2      Christopher Nolan   292.58
# 3          David Fincher    37.03
# 4      Quentin Tarantino   107.93
# 5        Robert Zemeckis   330.25
# 6          Peter Jackson   315.54
# 7         Lana Wachowski   171.48
# 8          Peter Jackson   377.85
# 9   Francis Ford Coppola   134.97
# 10     Christopher Nolan   448.14

# %%
df.set_index('Runtime')
# Out:
#           Rank                     Title  Year  Score  Metascore  \
# Runtime
# 142          1  The Shawshank Redemption  1994    9.3       80.0
# 152          2           The Dark Knight  2008    9.0       84.0
# 148          3                 Inception  2010    8.8       74.0
# 139          4                Fight Club  1999    8.8       66.0
# 154          5              Pulp Fiction  1994    8.9       94.0
# ...        ...                       ...   ...    ...        ...
# 94        9996     When Night Is Falling  1995    6.6        NaN
# 95        9997                   Stachka  1925    7.6        NaN
# 85        9998        November Criminals  2017    5.3       31.0
# 114       9999                       120  2008    7.3        NaN
# 81       10000                The Terror  1963    5.0        NaN
#
#                              Genre     Vote              Director  Revenue  \
# Runtime
# 142                          Drama  2011509        Frank Darabont    28.34
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# ...

# %%
df.set_index('Runtime', inplace= True)
df.index
# Out:
# Int64Index([142, 152, 148, 139, 154, 142, 178, 136, 201, 175,
#             ...
#             103,  90, 125, 105,  94,  94,  95,  85, 114,  81],
#            dtype='int64', name='Runtime', length=10000)

# %%
df.reset_index(inplace=True)
df
# Out:
#       Runtime   Rank                     Title  Year  Score  Metascore  \
# 0         142      1  The Shawshank Redemption  1994    9.3       80.0
# 1         152      2           The Dark Knight  2008    9.0       84.0
# 2         148      3                 Inception  2010    8.8       74.0
# 3         139      4                Fight Club  1999    8.8       66.0
# 4         154      5              Pulp Fiction  1994    8.9       94.0
# ...       ...    ...                       ...   ...    ...        ...
# 9995       94   9996     When Night Is Falling  1995    6.6        NaN
# 9996       95   9997                   Stachka  1925    7.6        NaN
# 9997       85   9998        November Criminals  2017    5.3       31.0
# 9998      114   9999                       120  2008    7.3        NaN
# 9999       81  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Revenue  \
# ...

# %%
df = pd.read_csv('movies.csv', index_col = 'Vote')
df
# Out:
#           Rank                     Title  Year  Score  Metascore  \
# Vote
# 2011509      1  The Shawshank Redemption  1994    9.3       80.0
# 1980200      2           The Dark Knight  2008    9.0       84.0
# 1760209      3                 Inception  2010    8.8       74.0
# 1609459      4                Fight Club  1999    8.8       66.0
# 1570194      5              Pulp Fiction  1994    8.9       94.0
# ...        ...                       ...   ...    ...        ...
# 6022      9996     When Night Is Falling  1995    6.6        NaN
# 6021      9997                   Stachka  1925    7.6        NaN
# 6020      9998        November Criminals  2017    5.3       31.0
# 6018      9999                       120  2008    7.3        NaN
# 6015     10000                The Terror  1963    5.0        NaN
#
#                              Genre              Director  Runtime  Revenue  \
# Vote
# 2011509                      Drama        Frank Darabont      142    28.34
# ...

# %%
df.loc[6015]
# Out:
# Rank                                                       10000
# Title                                                 The Terror
# Year                                                        1963
# Score                                                        5.0
# Metascore                                                    NaN
# Genre                                           Horror, Thriller
# Director                                            Roger Corman
# Runtime                                                       81
# Revenue                                                      NaN
# Description    A young officer in Napoleon's Army pursues a m...
# Name: 6015, dtype: object

# %%
df=pd.read_csv('movies.csv')
df
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# ...

# %%
df['Director']=='Christopher Nolan'
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Director, Length: 10000, dtype: bool

# %%
filtro = df['Director']=='Christopher Nolan'

# %%
df[filtro]
# Out:
#       Rank                  Title  Year  Score  Metascore  \
# 1        2        The Dark Knight  2008    9.0       84.0
# 2        3              Inception  2010    8.8       74.0
# 10      11  The Dark Knight Rises  2012    8.4       78.0
# 13      14           Interstellar  2014    8.6       74.0
# 16      17          Batman Begins  2005    8.3       70.0
# 24      25           The Prestige  2006    8.5       66.0
# 27      28                Memento  2000    8.5       80.0
# 229    230                Dunkirk  2017    7.9       94.0
# 551    552               Insomnia  2002    7.2       78.0
# 2102  2103              Following  1998    7.6       60.0
#
#                             Genre     Vote           Director  Runtime  \
# 1            Action, Crime, Drama  1980200  Christopher Nolan      152
# 2       Action, Adventure, Sci-Fi  1760209  Christopher Nolan      148
# 10               Action, Thriller  1338413  Christopher Nolan      164
# ...

# %%
df.loc[filtro]
# Out:
#       Rank                  Title  Year  Score  Metascore  \
# 1        2        The Dark Knight  2008    9.0       84.0
# 2        3              Inception  2010    8.8       74.0
# 10      11  The Dark Knight Rises  2012    8.4       78.0
# 13      14           Interstellar  2014    8.6       74.0
# 16      17          Batman Begins  2005    8.3       70.0
# 24      25           The Prestige  2006    8.5       66.0
# 27      28                Memento  2000    8.5       80.0
# 229    230                Dunkirk  2017    7.9       94.0
# 551    552               Insomnia  2002    7.2       78.0
# 2102  2103              Following  1998    7.6       60.0
#
#                             Genre     Vote           Director  Runtime  \
# 1            Action, Crime, Drama  1980200  Christopher Nolan      152
# 2       Action, Adventure, Sci-Fi  1760209  Christopher Nolan      148
# 10               Action, Thriller  1338413  Christopher Nolan      164
# ...

# %%
df.loc[filtro, 'Title']
# Out:
# 1             The Dark Knight
# 2                   Inception
# 10      The Dark Knight Rises
# 13               Interstellar
# 16              Batman Begins
# 24               The Prestige
# 27                    Memento
# 229                   Dunkirk
# 551                  Insomnia
# 2102                Following
# Name: Title, dtype: object

# %%
filtro1 = (df['Director']=='Christopher Nolan')&(df['Score']>=8.5)

# %%
filtro1
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df[filtro1]
# Out:
#     Rank            Title  Year  Score  Metascore                      Genre  \
# 1      2  The Dark Knight  2008    9.0       84.0       Action, Crime, Drama
# 2      3        Inception  2010    8.8       74.0  Action, Adventure, Sci-Fi
# 13    14     Interstellar  2014    8.6       74.0   Adventure, Drama, Sci-Fi
# 24    25     The Prestige  2006    8.5       66.0     Drama, Mystery, Sci-Fi
# 27    28          Memento  2000    8.5       80.0          Mystery, Thriller
#
#        Vote           Director  Runtime  Revenue  \
# 1   1980200  Christopher Nolan      152   534.86
# 2   1760209  Christopher Nolan      148   292.58
# 13  1223159  Christopher Nolan      169   188.02
# 24  1022475  Christopher Nolan      130    53.09
# 27   997174  Christopher Nolan      113    25.54
#
#                                           Description
# 1   When the menace known as the Joker emerges fro...
# 2   A thief who steals corporate secrets through t...
# ...

# %%
filtro1 = (df['Director']=='Christopher Nolan')|(df['Score']>=8.5)
df[filtro1]
# Out:
#       Rank                     Title  Year  Score  Metascore  \
# 0        1  The Shawshank Redemption  1994    9.3       80.0
# 1        2           The Dark Knight  2008    9.0       84.0
# 2        3                 Inception  2010    8.8       74.0
# 3        4                Fight Club  1999    8.8       66.0
# 4        5              Pulp Fiction  1994    8.9       94.0
# ...    ...                       ...   ...    ...        ...
# 9161  9162                     Aruvi  2016    8.9        NaN
# 9294  9295            Canim Kardesim  1973    8.8        NaN
# 9603  9604             Aloko Udapadi  2017    9.6        NaN
# 9629  9630                Graves End  2005    8.8        NaN
# 9974  9975                     Zübük  1980    8.5        NaN
#
#                           Genre     Vote                   Director  Runtime  \
# 0                         Drama  2011509             Frank Darabont      142
# ...

# %%
df[-filtro1]
# Out:
#        Rank                    Title  Year  Score  Metascore  \
# 15       16         Django Unchained  2012    8.4       81.0
# 17       18        Avengers Assemble  2012    8.1       69.0
# 20       21     Inglourious Basterds  2009    8.3       69.0
# 26       27                   Avatar  2009    7.8       83.0
# 28       29  The Wolf of Wall Street  2013    8.2       75.0
# ...     ...                      ...   ...    ...        ...
# 9995   9996    When Night Is Falling  1995    6.6        NaN
# 9996   9997                  Stachka  1925    7.6        NaN
# 9997   9998       November Criminals  2017    5.3       31.0
# 9998   9999                      120  2008    7.3        NaN
# 9999  10000               The Terror  1963    5.0        NaN
#
#                            Genre     Vote              Director  Runtime  \
# 15                Drama, Western  1159647     Quentin Tarantino      165
# 17     Action, Adventure, Sci-Fi  1130818           Joss Whedon      143
# ...

# %%
high_score = df['Score']>=9.3
df[high_score]
# Out:
#       Rank                     Title  Year  Score  Metascore  \
# 0        1  The Shawshank Redemption  1994    9.3       80.0
# 1645  1646                    Dag II  2016    9.4        NaN
# 3914  3915            Hababam Sinifi  1975    9.4        NaN
# 5482  5483                  Aynabaji  2016    9.4        NaN
# 5979  5980                    Wheels  2014    9.4        NaN
# 9603  9604             Aloko Udapadi  2017    9.6        NaN
#
#                          Genre     Vote                Director  Runtime  \
# 0                        Drama  2011509          Frank Darabont      142
# 1645                Drama, War    98484            Alper Caglar      135
# 3914             Comedy, Drama    32457           Ertem Egilmez       87
# 5482  Crime, Mystery, Thriller    17926  Amitabh Reza Chowdhury      147
# 5979                     Drama    15447           Tim Gagliardo      115
# 9603            Drama, History     6450        Chathra Weeraman      113
#
# ...

# %%
df.loc[high_score, ['Title', 'Revenue']]
# Out:
#                          Title  Revenue
# 0     The Shawshank Redemption    28.34
# 1645                    Dag II      NaN
# 3914            Hababam Sinifi      NaN
# 5482                  Aynabaji      NaN
# 5979                    Wheels      NaN
# 9603             Aloko Udapadi      NaN

# %%
df['Genre']
# Out:
# 0                           Drama
# 1            Action, Crime, Drama
# 2       Action, Adventure, Sci-Fi
# 3                           Drama
# 4                    Crime, Drama
#                   ...
# 9995               Drama, Romance
# 9996                        Drama
# 9997        Crime, Drama, Mystery
# 9998          Drama, History, War
# 9999             Horror, Thriller
# Name: Genre, Length: 10000, dtype: object

# %%
genero = ['Drama', 'Comedy']
filtro3 = df['Genre'].isin(genero)
df.loc[filtro3, 'Genre']
# Out:
# 0        Drama
# 3        Drama
# 31       Drama
# 52       Drama
# 79       Drama
#          ...
# 9963     Drama
# 9965     Drama
# 9977    Comedy
# 9990     Drama
# 9996     Drama
# Name: Genre, Length: 839, dtype: object

# %%
filtro4 = df['Genre'].str.contains('Drama')
df.loc[filtro4, 'Genre']
# Out:
# 0                       Drama
# 1        Action, Crime, Drama
# 3                       Drama
# 4                Crime, Drama
# 5              Drama, Romance
#                 ...
# 9993            Comedy, Drama
# 9995           Drama, Romance
# 9996                    Drama
# 9997    Crime, Drama, Mystery
# 9998      Drama, History, War
# Name: Genre, Length: 5572, dtype: object

# %%
df.columns= [x.upper() for x in df.columns]
df.columns
# Out:
# Index(['RANK', 'TITLE', 'YEAR', 'SCORE', 'METASCORE', 'GENRE', 'VOTE',
#        'DIRECTOR', 'RUNTIME', 'REVENUE', 'DESCRIPTION'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.rename(columns={'TITLE': 'English title', 'SCORE':'Puntuacion'},inplace=True)
df.columns
# Out:
# Index(['RANK', 'English title', 'YEAR', 'Puntuacion', 'METASCORE', 'GENRE',
#        'VOTE', 'DIRECTOR', 'RUNTIME', 'REVENUE', 'DESCRIPTION'],
#       dtype='object')

# %%
df.loc[0]
# Out:
# RANK                                                             1
# English title                             The Shawshank Redemption
# YEAR                                                          1994
# Puntuacion                                                     9.3
# METASCORE                                                     80.0
# GENRE                                                        Drama
# VOTE                                                       2011509
# DIRECTOR                                            Frank Darabont
# RUNTIME                                                        142
# REVENUE                                                      28.34
# DESCRIPTION      Two imprisoned men bond over a number of years...
# Name: 0, dtype: object

# %%
df.loc[0,['English title', 'Puntuacion']]
# Out:
# English title    The Shawshank Redemption
# Puntuacion                            9.3
# Name: 0, dtype: object

# %%
df.loc[0,['English title', 'Puntuacion']] = ['The mandalorian', 9.5]
df.loc[0]
# Out:
# RANK                                                             1
# English title                                      The mandalorian
# YEAR                                                          1994
# Puntuacion                                                     9.5
# METASCORE                                                     80.0
# GENRE                                                        Drama
# VOTE                                                       2011509
# DIRECTOR                                            Frank Darabont
# RUNTIME                                                        142
# REVENUE                                                      28.34
# DESCRIPTION      Two imprisoned men bond over a number of years...
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# RANK                                                             1
# English title                                      The mandalorian
# YEAR                                                          1994
# Puntuacion                                                     9.5
# METASCORE                                                     80.0
# GENRE                                                        Drama
# VOTE                                                       2011509
# DIRECTOR                                            Frank Darabont
# RUNTIME                                                        142
# REVENUE                                                      28.34
# DESCRIPTION      Two imprisoned men bond over a number of years...
# Name: 0, dtype: object

# %%
filtro5 = (df['English title'])=='Batman'
df.loc[filtro5, 'YEAR']
# Out:
# 414    1989
# Name: YEAR, dtype: int64

# %%
df.loc[filtro5, 'YEAR']=2000
df.loc[filtro5, 'YEAR']
# Out:
# 414    2000
# Name: YEAR, dtype: int64

# %%
df['English title'].apply(len)
# Out:
# 0       15
# 1       15
# 2        9
# 3       10
# 4       12
#         ..
# 9995    21
# 9996     7
# 9997    18
# 9998     3
# 9999    10
# Name: English title, Length: 10000, dtype: int64

# %%
def actualizarTitulo(titulo):
    return titulo.upper()

df['English title']=df['English title'].apply(actualizarTitulo)

# %%
df
# Out:
#        RANK          English title  YEAR  Puntuacion  METASCORE  \
# 0         1        THE MANDALORIAN  1994         9.5       80.0
# 1         2        THE DARK KNIGHT  2008         9.0       84.0
# 2         3              INCEPTION  2010         8.8       74.0
# 3         4             FIGHT CLUB  1999         8.8       66.0
# 4         5           PULP FICTION  1994         8.9       94.0
# ...     ...                    ...   ...         ...        ...
# 9995   9996  WHEN NIGHT IS FALLING  1995         6.6        NaN
# 9996   9997                STACHKA  1925         7.6        NaN
# 9997   9998     NOVEMBER CRIMINALS  2017         5.3       31.0
# 9998   9999                    120  2008         7.3        NaN
# 9999  10000             THE TERROR  1963         5.0        NaN
#
#                           GENRE     VOTE              DIRECTOR  RUNTIME  \
# 0                         Drama  2011509        Frank Darabont      142
# ...

# %%
df['English title'] = df['English title'].apply(lambda x: x.lower())
df
# Out:
#        RANK          English title  YEAR  Puntuacion  METASCORE  \
# 0         1        the mandalorian  1994         9.5       80.0
# 1         2        the dark knight  2008         9.0       84.0
# 2         3              inception  2010         8.8       74.0
# 3         4             fight club  1999         8.8       66.0
# 4         5           pulp fiction  1994         8.9       94.0
# ...     ...                    ...   ...         ...        ...
# 9995   9996  when night is falling  1995         6.6        NaN
# 9996   9997                stachka  1925         7.6        NaN
# 9997   9998     november criminals  2017         5.3       31.0
# 9998   9999                    120  2008         7.3        NaN
# 9999  10000             the terror  1963         5.0        NaN
#
#                           GENRE     VOTE              DIRECTOR  RUNTIME  \
# 0                         Drama  2011509        Frank Darabont      142
# ...

# %%
len(df['English title'])
# Out:
# 10000

# %%
df['YEAR'].replace({1994:1000})
# Out:
# 0       1000
# 1       2008
# 2       2010
# 3       1999
# 4       1000
#         ...
# 9995    1995
# 9996    1925
# 9997    2017
# 9998    2008
# 9999    1963
# Name: YEAR, Length: 10000, dtype: int64

# %%
df.rename(columns={'YEAR': 'AÑO'}, inplace=True)

# %%
df
# Out:
#        RANK          English title   AÑO  Puntuacion  METASCORE  \
# 0         1        the mandalorian  1994         9.5       80.0
# 1         2        the dark knight  2008         9.0       84.0
# 2         3              inception  2010         8.8       74.0
# 3         4             fight club  1999         8.8       66.0
# 4         5           pulp fiction  1994         8.9       94.0
# ...     ...                    ...   ...         ...        ...
# 9995   9996  when night is falling  1995         6.6        NaN
# 9996   9997                stachka  1925         7.6        NaN
# 9997   9998     november criminals  2017         5.3       31.0
# 9998   9999                    120  2008         7.3        NaN
# 9999  10000             the terror  1963         5.0        NaN
#
#                           GENRE     VOTE              DIRECTOR  RUNTIME  \
# 0                         Drama  2011509        Frank Darabont      142
# ...

# %%
df['AÑO']
# Out:
# 0       1994
# 1       2008
# 2       2010
# 3       1999
# 4       1994
#         ...
# 9995    1995
# 9996    1925
# 9997    2017
# 9998    2008
# 9999    1963
# Name: AÑO, Length: 10000, dtype: int64

# %%
df =pd.read_csv('movies.csv')

# %%
df
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# ...

# %%
df['Title']+ ' ' + df['Director']
# Out:
# 0       The Shawshank Redemption Frank Darabont
# 1             The Dark Knight Christopher Nolan
# 2                   Inception Christopher Nolan
# 3                      Fight Club David Fincher
# 4                Pulp Fiction Quentin Tarantino
#                          ...
# 9995      When Night Is Falling Patricia Rozema
# 9996               Stachka Sergei M. Eisenstein
# 9997           November Criminals Sacha Gervasi
# 9998                             120 Özhan Eren
# 9999                    The Terror Roger Corman
# Length: 10000, dtype: object

# %%
(df['Score']+(df['Metascore']/10))/2
# Out:
# 0       8.65
# 1       8.70
# 2       8.10
# 3       7.70
# 4       9.15
#         ...
# 9995     NaN
# 9996     NaN
# 9997    4.20
# 9998     NaN
# 9999     NaN
# Length: 10000, dtype: float64

# %%
df['Total score'] = (df['Score']+(df['Metascore']/10))/2
df
# Out:
#        Rank                     Title  Year  Score  Metascore  ...  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0  ...
# 1         2           The Dark Knight  2008    9.0       84.0  ...
# 2         3                 Inception  2010    8.8       74.0  ...
# 3         4                Fight Club  1999    8.8       66.0  ...
# 4         5              Pulp Fiction  1994    8.9       94.0  ...
# ...     ...                       ...   ...    ...        ...  ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN  ...
# 9996   9997                   Stachka  1925    7.6        NaN  ...
# 9997   9998        November Criminals  2017    5.3       31.0  ...
# 9998   9999                       120  2008    7.3        NaN  ...
# 9999  10000                The Terror  1963    5.0        NaN  ...
#
#                   Director  Runtime Revenue  \
# 0           Frank Darabont      142   28.34
# 1        Christopher Nolan      152  534.86
# ...

# %%
df.drop(columns=['Total score'], inplace = True)
df
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# ...

# %%
df.drop(index=1)
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# 5         6              Forrest Gump  1994    8.8       82.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 2     Action, Adventure, Sci-Fi  1760209     Christopher Nolan      148
# ...

# %%
df.drop(index=df[df['Score']==9.3].index)
# Out:
#        Rank                  Title  Year  Score  Metascore  \
# 1         2        The Dark Knight  2008    9.0       84.0
# 2         3              Inception  2010    8.8       74.0
# 3         4             Fight Club  1999    8.8       66.0
# 4         5           Pulp Fiction  1994    8.9       94.0
# 5         6           Forrest Gump  1994    8.8       82.0
# ...     ...                    ...   ...    ...        ...
# 9995   9996  When Night Is Falling  1995    6.6        NaN
# 9996   9997                Stachka  1925    7.6        NaN
# 9997   9998     November Criminals  2017    5.3       31.0
# 9998   9999                    120  2008    7.3        NaN
# 9999  10000             The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# 2     Action, Adventure, Sci-Fi  1760209     Christopher Nolan      148
# ...

# %%
filtro6=df['Score']==9.3
df.drop(index=df[filtro6].index)
# Out:
#        Rank                  Title  Year  Score  Metascore  \
# 1         2        The Dark Knight  2008    9.0       84.0
# 2         3              Inception  2010    8.8       74.0
# 3         4             Fight Club  1999    8.8       66.0
# 4         5           Pulp Fiction  1994    8.9       94.0
# 5         6           Forrest Gump  1994    8.8       82.0
# ...     ...                    ...   ...    ...        ...
# 9995   9996  When Night Is Falling  1995    6.6        NaN
# 9996   9997                Stachka  1925    7.6        NaN
# 9997   9998     November Criminals  2017    5.3       31.0
# 9998   9999                    120  2008    7.3        NaN
# 9999  10000             The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# 2     Action, Adventure, Sci-Fi  1760209     Christopher Nolan      148
# ...

# %%
df.sort_values(by='Score')
# Out:
#       Rank                           Title  Year  Score  Metascore  \
# 8972  8973                        Smolensk  2016    1.3        NaN
# 3632  3633  Cumali Ceber: Allah Seni Alsin  2017    1.3        NaN
# 9852  9853                  Kartoffelsalat  2015    1.3        NaN
# 6340  6341                Saving Christmas  2014    1.5       18.0
# 4422  4423                  Kod Adi K.O.Z.  2015    1.6        NaN
# ...    ...                             ...   ...    ...        ...
# 3914  3915                  Hababam Sinifi  1975    9.4        NaN
# 5482  5483                        Aynabaji  2016    9.4        NaN
# 1645  1646                          Dag II  2016    9.4        NaN
# 5979  5980                          Wheels  2014    9.4        NaN
# 9603  9604                   Aloko Udapadi  2017    9.6        NaN
#
#                          Genre   Vote                Director  Runtime  \
# 8972           Drama, Thriller   7270           Antoni Krauze      120
# ...

# %%
df.sort_values(by='Score', ascending=False)
# Out:
#       Rank                           Title  Year  Score  Metascore  \
# 9603  9604                   Aloko Udapadi  2017    9.6        NaN
# 1645  1646                          Dag II  2016    9.4        NaN
# 3914  3915                  Hababam Sinifi  1975    9.4        NaN
# 5979  5980                          Wheels  2014    9.4        NaN
# 5482  5483                        Aynabaji  2016    9.4        NaN
# ...    ...                             ...   ...    ...        ...
# 4422  4423                  Kod Adi K.O.Z.  2015    1.6        NaN
# 6340  6341                Saving Christmas  2014    1.5       18.0
# 3632  3633  Cumali Ceber: Allah Seni Alsin  2017    1.3        NaN
# 8972  8973                        Smolensk  2016    1.3        NaN
# 9852  9853                  Kartoffelsalat  2015    1.3        NaN
#
#                          Genre   Vote                Director  Runtime  \
# 9603            Drama, History   6450        Chathra Weeraman      113
# ...

# %%
df.sort_index()
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# ...

# %%
df.sort_values(by='Title', inplace=True)

# %%
df
# Out:
#       Rank                               Title  Year  Score  Metascore  \
# 3165  3166                                 '71  2014    7.2       83.0
# 6645  6646                         'A' gai wak  1983    7.4        NaN
# 8655  8656                       'A' gai wak 2  1987    7.2        NaN
# 9286  9287           'I Know Where I'm Going!'  1945    7.6        NaN
# 6794  6795  (T)Raumschiff Surprise - Periode 1  2004    5.4        NaN
# ...    ...                                 ...   ...    ...        ...
# 7702  7703                         Çalgi Çengi  2011    7.3        NaN
# 8747  8748                         Çiçek Abbas  1982    8.2        NaN
# 5929  5930                      Çöpçüler Krali  1977    8.7        NaN
# 8529  8530                        Ölümlü Dünya  2018    8.0        NaN
# 5741  5742                           Üç Maymun  2008    7.4       73.0
#
#                         Genre   Vote           Director  Runtime  Revenue  \
# ...

# %%
df[['Title', 'Score']].head(10)
# Out:
#                                      Title  Score
# 3165                                   '71    7.2
# 6645                           'A' gai wak    7.4
# 8655                         'A' gai wak 2    7.2
# 9286             'I Know Where I'm Going!'    7.6
# 6794    (T)Raumschiff Surprise - Periode 1    5.4
# 4349               *batteries not included    6.6
# 5579  ...E tu vivrai nel terrore! L'aldilà    6.9
# 4399               ...and justice for all.    7.4
# 8686                                  0.45    5.7
# 6144                                 02:22    5.7

# %%
df.sort_values(by=['Genre', 'Score'], ascending=[True, False], inplace=True)
df[['Score','Genre']].head(10)
# Out:
#       Score   Genre
# 9369    7.3  Action
# 7584    7.2  Action
# 9647    6.2  Action
# 4356    6.2  Action
# 5412    5.8  Action
# 7820    5.5  Action
# 2648    5.4  Action
# 6935    5.0  Action
# 8344    4.0  Action
# 9008    1.7  Action

# %%
df['Runtime'].nlargest(5)
# Out:
# 8862    450
# 5377    366
# 6957    325
# 2401    321
# 5220    317
# Name: Runtime, dtype: int64

# %%
df.nlargest(10, 'Runtime')
# Out:
#       Rank                    Title  Year  Score  Metascore  \
# 8862  8863               Sátántangó  1994    8.5        NaN
# 5377  5378       La meglio gioventù  2003    8.5       89.0
# 6957  6958            Heaven's Gate  1980    6.8       57.0
# 2401  2402       Gangs of Wasseypur  2012    8.2       89.0
# 5220  5221                Novecento  1976    7.7        NaN
# 4676  4677               Gettysburg  1993    7.7        NaN
# 9771  9772  Dr. Mabuse, der Spieler  1922    7.9        NaN
# 3838  3839                   Hamlet  1996    7.8        NaN
# 9905  9906                 Napoleon  1927    7.6        NaN
# 530    531       Gone with the Wind  1939    8.2       97.0
#
#                           Genre    Vote               Director  Runtime  \
# 8862                      Drama    7449              Béla Tarr      450
# 5377             Drama, Romance   18572  Marco Tullio Giordana      366
# 6957  Adventure, Drama, Western   11718         Michael Cimino      325
# ...

# %%
df.nsmallest(10, 'Runtime')
# Out:
#       Rank                                              Title  Year  Score  \
# 4095  4096                                       Sherlock Jr.  1924    8.2
# 7977  7978                                 Hotarubi no mori e  2011    7.9
# 4839  4840                                 Koto no ha no niwa  2013    7.6
# 9149  9150                                The Call of Cthulhu  2005    7.3
# 7166  7167                            Blood: The Last Vampire  2000    6.7
# 8547  8548  Dragon Ball Z: Fukkatsu no Fusion!! Gokuu to V...  1995    7.8
# 9652  9653  Doragon bôru Z: Ryûken bakuhatsu!! Gokû ga yar...  1995    7.6
# 9207  9208                           The Beast of Yucca Flats  1961    2.4
# 8602  8603                                      Seven Chances  1925    8.0
# 8574  8575                                      The Navigator  1924    8.0
#
#       Metascore                      Genre   Vote            Director  \
# 4095        NaN    Action, Comedy, Romance  29985       Buster Keaton
# ...

# %%
df['Score'].mean()
# Out:
# 6.627529999999983

# %%
df['Score'].describe()
# Out:
# count    10000.000000
# mean         6.627530
# std          1.041204
# min          1.300000
# 25%          6.000000
# 50%          6.700000
# 75%          7.400000
# max          9.600000
# Name: Score, dtype: float64

# %%
df['Genre'].value_counts()
# Out:
# Comedy, Drama, Romance        494
# Drama                         482
# Comedy, Drama                 407
# Drama, Romance                365
# Comedy                        357
#                              ...
# Crime                           1
# Horror, Music, Mystery          1
# Comedy, Crime, Adventure        1
# Animation, Drama, Thriller      1
# Action, Fantasy, War            1
# Name: Genre, Length: 486, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# 7.2    431
# 7.3    422
# 7.1    391
# 6.8    387
# 6.6    386
#       ...
# 1.5      1
# 1.6      1
# 9.2      1
# 9.3      1
# 1.7      1
# Name: Score, Length: 82, dtype: int64

# %%
df['Score'].value_counts(normalize=True)
# Out:
# 7.2    0.0431
# 7.3    0.0422
# 7.1    0.0391
# 6.8    0.0387
# 6.6    0.0386
#         ...
# 1.5    0.0001
# 1.6    0.0001
# 9.2    0.0001
# 9.3    0.0001
# 1.7    0.0001
# Name: Score, Length: 82, dtype: float64

# %%
genre_group=df.groupby(['Genre'])

# %%
genre_group.get_group('Adventure, Comedy, Sport')
# Out:
#       Rank  Title  Year  Score  Metascore                     Genre   Vote  \
# 7200  7201  Grind  2003    6.0       30.0  Adventure, Comedy, Sport  11040
#
#             Director  Runtime  Revenue  \
# 7200  Casey La Scala      105     5.11
#
#                                             Description
# 7200  Four skaters follow their idol on his summer t...

# %%
filtro7= df['Genre']=='Drama'

# %%
df.loc[filtro7]
# Out:
#       Rank                     Title  Year  Score  Metascore  Genre     Vote  \
# 5979  5980                    Wheels  2014    9.4        NaN  Drama    15447
# 0        1  The Shawshank Redemption  1994    9.3       80.0  Drama  2011509
# 9161  9162                     Aruvi  2016    8.9        NaN  Drama     7021
# 4996  4997                     Anand  1971    8.8        NaN  Drama    21209
# 9294  9295            Canim Kardesim  1973    8.8        NaN  Drama     6853
# ...    ...                       ...   ...    ...        ...    ...      ...
# 3584  3585            God's Not Dead  2014    4.8       16.0  Drama    37124
# 2703  2704                 Showgirls  1995    4.7       16.0  Drama    55966
# 7674  7675          God's Not Dead 2  2016    4.4       22.0  Drama     9717
# 8926  8927            Glen or Glenda  1953    4.2        NaN  Drama     7338
# 2343  2344                  The Room  2003    3.6        NaN  Drama    67311
#
# ...

# %%
df.loc[filtro7]['Score'].value_counts()
# Out:
# 7.4    38
# 7.6    36
# 7.8    35
# 7.3    32
# 7.2    30
# 8.0    28
# 8.1    28
# 7.1    23
# 7.5    21
# 7.9    20
# 6.8    19
# 7.7    19
# 7.0    14
# 6.9    12
# 6.4    12
# 6.5    12
# 8.2    11
# 8.3    11
# 6.6    10
# 6.2     9
# 6.7     9
# 6.3     6
# 5.9     5
# 5.7     5
# 8.4     4
# 6.0     4
# 5.3     3
# 8.5     3
# 5.5     3
# 8.8     3
# 6.1     2
# 4.8     2
# 5.6     2
# 9.4     1
# 3.6     1
# 4.7     1
# 4.4     1
# 9.3     1
# 8.7     1
# 5.4     1
# 5.8     1
# 4.2     1
# 8.9     1
# 5.0     1
# Name: Score, dtype: int64

# %%
genre_group['Score'].value_counts().head(15)
# Out:
# Genre              Score
# Action             6.2      2
#                    1.7      1
#                    4.0      1
#                    5.0      1
#                    5.4      1
#                    5.5      1
#                    5.8      1
#                    7.2      1
#                    7.3      1
# Action, Adventure  5.4      2
#                    6.1      2
#                    7.6      2
#                    4.8      1
#                    5.1      1
#                    5.2      1
# Name: Score, dtype: int64

# %%
genre_group['Score'].value_counts(normalize=True).loc['Action, Adventure, Comedy']
# Out:
# Score
# 6.7    0.058394
# 6.8    0.051095
# 5.7    0.043796
# 5.8    0.043796
# 6.1    0.043796
# 6.2    0.043796
# 6.6    0.043796
# 7.0    0.043796
# 5.2    0.036496
# 5.5    0.036496
# 6.0    0.036496
# 6.3    0.036496
# 7.3    0.036496
# 5.0    0.029197
# 5.4    0.029197
# 7.1    0.029197
# 3.5    0.021898
# 4.2    0.021898
# 4.4    0.021898
# 5.6    0.021898
# 6.5    0.021898
# 4.8    0.014599
# 4.9    0.014599
# 5.1    0.014599
# 6.4    0.014599
# 6.9    0.014599
# 7.2    0.014599
# 7.7    0.014599
# 8.2    0.014599
# 1.8    0.007299
# 1.9    0.007299
# 2.8    0.007299
# 3.0    0.007299
# 3.7    0.007299
# 3.8    0.007299
# 4.1    0.007299
# 4.3    0.007299
# 4.5    0.007299
# 4.6    0.007299
# 4.7    0.007299
# 5.3    0.007299
# 5.9    0.007299
# 7.6    0.007299
# 7.8    0.007299
# 7.9    0.007299
# 8.0    0.007299
# 8.1    0.007299
# Name: Score, dtype: float64

# %%
genre_group['Score'].median()
# Out:
# Genre
# Action                          5.65
# Action, Adventure               6.30
# Action, Adventure, Biography    6.95
# Action, Adventure, Comedy       6.10
# Action, Adventure, Crime        6.00
#                                 ...
# Thriller, Mystery               8.80
# Thriller, War                   6.65
# Thriller, Western               6.90
# War                             7.40
# Western                         7.40
# Name: Score, Length: 486, dtype: float64

# %%
genre_group['Score'].agg(['mean', 'median']).loc['War']
# Out:
# mean      7.4
# median    7.4
# Name: War, dtype: float64

# %%
filtro8 = df['Genre'] == 'Western'
df.loc[filtro8]['Title']
# Out:
# 111     The Good, the Bad and the Ugly
# 521       Once Upon a Time in the West
# 779             For a Few Dollars More
# 911               A Fistful of Dollars
# 2623            The Outlaw Josey Wales
# 6985                 The Great Silence
# 8506                    The Gunfighter
# 7346             Ride the High Country
# 7614                            Hombre
# 6365          She Wore a Yellow Ribbon
# 8460              The Man from Laramie
# 3092                        Pale Rider
# 7724                          Big Jake
# 8363                    One-Eyed Jacks
# 6705           The Sons of Katie Elder
# 5782              How the West Was Won
# 4073                     Hang 'Em High
# 9638                      Nevada Smith
# 8735                     The War Wagon
# 6183                          Joe Kidd
# Name: Title, dtype: object
